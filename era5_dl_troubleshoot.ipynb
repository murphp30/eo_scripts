# %%
# !export ECCODES_DIR=/home/pearse/eccodes

# %%
from pathlib import Path
import netCDF4
import h5py 
import xarray as xr

# %%
pwd
# Out:
# '/data/tapas/pearse/scripts'

# %%
for era_file in Path("/data/tapas/pearse/vietnam/ERA5/F56").glob("*[A-z].nc"):
    era_data = netCDF4.Dataset(era_file)
    print(era_file, era_data['swvl1'].shape)
# Out:
# /data/tapas/pearse/vietnam/ERA5/F56/05_2024_ssm.nc (744, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/10_2023_ssm.nc (744, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/08_2024_ssm.nc (336, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/02_2024_ssm.nc (696, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/04_2023_ssm.nc (720, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/04_2024_ssm.nc (720, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/11_2023_ssm.nc (720, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/07_2024_ssm.nc (720, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/06_2023_ssm.nc (720, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/02_2023_ssm.nc (672, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/07_2023_ssm.nc (744, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/01_2023_ssm.nc (672, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/08_2023_ssm.nc (744, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/03_2024_ssm.nc (744, 4, 5)
# /data/tapas/pearse/vietnam/ERA5/F56/01_2024_ssm.nc (744, 4, 5)
# ...

# %%
era_data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     GRIB_centre: ecmf
#     GRIB_centreDescription: European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre: 0
#     Conventions: CF-1.7
#     institution: European Centre for Medium-Range Weather Forecasts
#     history: 2024-09-04T08:51 GRIB to CDM+CF via cfgrib-0.9.14.0/ecCodes-2.36.0 with {"source": "data.grib", "filter_by_keys": {}, "encode_cf": ["parameter", "time", "geography", "vertical"]}
#     dimensions(sizes): valid_time(720), latitude(4), longitude(5)
#     variables(dimensions): int64 number(), int64 valid_time(valid_time), float64 latitude(latitude), float64 longitude(longitude), <class 'str'> expver(valid_time), float32 tp(valid_time, latitude, longitude), float32 skt(valid_time, latitude, longitude), float32 swvl1(valid_time, latitude, longitude)
#     groups:

# %%
# !HDF5_USE_FILE_LOCKING=FALSE

# %%
# !whoami
# Out:
# pearse

# %%
era_data = netCDF4.Dataset("/data/tapas/pearse/vietnam/ERA5/F56/07_2024_ssm.nc", "r+")# format="NETCDF4")

# %%
era_data['valid_time'][:] += 30*24*60*60

# %%
era_data.variables.keys()
# Out:
# dict_keys(['number', 'valid_time', 'latitude', 'longitude', 'expver', 'tp', 'skt', 'swvl1'])

# %%
import numpy as np

# %%
era_data['swvl1'][:] = np.ma.MaskedArray(era_data['swvl1'][:].data, ~era_data['swvl1'][:].mask)

# %%
era_data.close()

# %%
Downloaded_datasets = list(Path("/data/tapas/pearse/vietnam/ERA5/F56").glob("*[A-z].nc"))

# %%
ds = xr.open_mfdataset(Downloaded_datasets, combine='by_coords')
ERA5_dir = "/data/tapas/pearse/vietnam/ERA5/F56"
start_date = '20230104' # format is YYYYMMDD
end_date = '20240815' # format is YYYYMMDD
ERA5_sm_filename = ERA5_dir+"F56_"+start_date+"_"+end_date+".nc"

# %%
ds
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (valid_time: 13416, latitude: 4, longitude: 5)
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 107kB 2023-01-04 ... 2024-08-15T2...
#   * latitude    (latitude) float64 32B 10.6 10.5 10.4 10.3
#   * longitude   (longitude) float64 40B 105.8 105.9 106.0 106.1 106.2
#     expver      (valid_time) <U4 215kB dask.array<chunksize=(672,), meta=np.ndarray>
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 1MB dask.array<chunksize=(336, 2, 3), meta=np.ndarray>
#     skt         (valid_time, latitude, longitude) float32 1MB dask.array<chunksize=(336, 2, 3), meta=np.ndarray>
#     swvl1       (valid_time, latitude, longitude) float32 1MB dask.array<chunksize=(336, 2, 3), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
# ...

# %%
ds.to_netcdf(ERA5_sm_filename) # Export netcdf file
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ds.to_netcdf(ERA5_sm_filename) # Export netcdf file
#
# File ~/.pyenv/versions/3.12.3/envs/tapas/lib/python3.12/site-packages/xarray/core/dataset.py:2329, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    2326     encoding = {}
#    2327 from xarray.backends.api import to_netcdf
# -> 2329 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    2330     self,
#    2331     path,
#    2332     mode=mode,
#    2333     format=format,
#    2334     group=group,
#    2335     engine=engine,
#    2336     encoding=encoding,
#    2337     unlimited_dims=unlimited_dims,
#    2338     compute=compute,
#    2339     multifile=False,
#    2340     invalid_netcdf=invalid_netcdf,
#    2341 )
#
# ...

# %%
ds = xr.open_dataset("/data/tapas/pearse/vietnam/ERA5/F56/07_2024_ssm.grib", engine="cfgrib")
# Out:
# /home/pearse/.pyenv/versions/3.12.3/envs/tapas/lib/python3.12/site-packages/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds = xr.open_dataset("/data/tapas/pearse/vietnam/ERA5/F56/07_2024_ssm.grib", engine="cfgrib")
#
# File ~/.pyenv/versions/3.12.3/envs/tapas/lib/python3.12/site-packages/xarray/backends/api.py:574, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     571 if from_array_kwargs is None:
#     572     from_array_kwargs = {}
# ...

# %%
xr_data
# Out:
# <xarray.Dataset> Size: 190kB
# Dimensions:     (valid_time: 720, latitude: 4, longitude: 5)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 6kB 2024-06-01 ... 2024-06-30T23:...
#   * latitude    (latitude) float64 32B 10.6 10.5 10.4 10.3
#   * longitude   (longitude) float64 40B 105.8 105.9 106.0 106.1 106.2
#     expver      (valid_time) <U4 12kB ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 58kB ...
#     skt         (valid_time, latitude, longitude) float32 58kB ...
#     swvl1       (valid_time, latitude, longitude) float32 58kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-09-04T08:51 GRIB to CDM+CF via cfgrib-0.9.1...
